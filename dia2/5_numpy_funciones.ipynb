# %% [markdown]
# # FUNCIONES MAS COMUNES EN NUMPY

# %%
import numpy as np

# %% [markdown]
# # SHAPE Y RESHAPE

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[5, 4],
#        [7, 4],
#        [3, 4]])

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr.ndim
# Out:
# 2

# %%
arr.reshape(1,6)
# Out:
# array([[5, 4, 7, 4, 3, 4]])

# %%
arr.ndim
# Out:
# 2

# %% [markdown]
# # MAX Y ARGMAX

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([ 5, 10,  1, 17, 19,  9,  4, 14,  4, 16])

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[ 5, 10,  1, 17, 19],
#        [ 9,  4, 14,  4, 16]])

# %%
arr.max()
# Out:
# np.int64(19)

# %%
matriz.max()
# Out:
# np.int64(19)

# %%
arr.argmax()
# Out:
# np.int64(4)

# %% [markdown]
# # MIN Y ARGMIN

# %%
arr.min()
# Out:
# np.int64(1)

# %%
matriz.min(0)
# Out:
# array([ 5,  4,  1,  4, 16])

# %% [markdown]
# # SORT

# %%
arr
# Out:
# array([ 5, 10,  1, 17, 19,  9,  4, 14,  4, 16])

# %%
arr.sort()
arr
# Out:
# array([ 1,  4,  4,  5,  9, 10, 14, 16, 17, 19])
