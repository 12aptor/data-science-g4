# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
penguins_df = sns.load_dataset('penguins')
penguins_df.dropna(inplace=True)
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %%
sns.heatmap(
    data=penguins_df.corr(numeric_only=True),
    cmap=sns.diverging_palette(20,230,as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    cbar_kws={'shrink':0.5},
    annot=True
)
# Out:
# <Axes: >

# %% [markdown]
# # CODIFICAMOS LA VARIABLE SEX PARA PODER INCLUIRLA EN EL HEATMAP DE CORRELACIONES

# %% [markdown]
# ## LABEL ENCODING

# %%
df_encoded = penguins_df.copy()

# %%
df_encoded['sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df_encoded['numeric_sex'] = df_encoded['sex'].map({'Female': 0, 'Male': 1})
df_encoded
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  numeric_sex
# 0         3750.0    Male            1
# 1         3800.0  Female            0
# 2         3250.0  Female            0
# 4         3450.0  Female            0
# 5         3650.0    Male            1
# ..           ...     ...          ...
# 338       4925.0  Female            0
# 340       4850.0  Female            0
# 341       5750.0    Male            1
# 342       5200.0  Female            0
# 343       5400.0    Male            1
#
# [333 rows x 8 columns]

# %%
df_encoded['numeric_sex'] = df_encoded['sex'].astype('category').cat.codes
df_encoded
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  numeric_sex
# 0         3750.0    Male            1
# 1         3800.0  Female            0
# 2         3250.0  Female            0
# 4         3450.0  Female            0
# 5         3650.0    Male            1
# ..           ...     ...          ...
# 338       4925.0  Female            0
# 340       4850.0  Female            0
# 341       5750.0    Male            1
# 342       5200.0  Female            0
# 343       5400.0    Male            1
#
# [333 rows x 8 columns]

# %%
sns.heatmap(
    data=df_encoded.corr(numeric_only=True),
    cmap=sns.diverging_palette(20,230,as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    cbar_kws={'shrink':0.5},
    annot=True
)
# Out:
# <Axes: >

# %% [markdown]
# # ONE HOT ENCODING

# %%
df_encoded = pd.get_dummies(df_encoded,columns=['island','species'],prefix='numeric', dtype=int)
df_encoded
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex  \
# 0              39.1           18.7              181.0       3750.0    Male
# 1              39.5           17.4              186.0       3800.0  Female
# 2              40.3           18.0              195.0       3250.0  Female
# 4              36.7           19.3              193.0       3450.0  Female
# 5              39.3           20.6              190.0       3650.0    Male
# ..              ...            ...                ...          ...     ...
# 338            47.2           13.7              214.0       4925.0  Female
# 340            46.8           14.3              215.0       4850.0  Female
# 341            50.4           15.7              222.0       5750.0    Male
# 342            45.2           14.8              212.0       5200.0  Female
# 343            49.9           16.1              213.0       5400.0    Male
#
#      numeric_sex  numeric_Biscoe  numeric_Dream  numeric_Torgersen  \
# 0              1               0              0                  1
# 1              0               0              0                  1
# 2              0               0              0                  1
# 4              0               0              0                  1
# 5              1               0              0                  1
# ..           ...             ...            ...                ...
# 338            0               1              0                  0
# 340            0               1              0                  0
# 341            1               1              0                  0
# 342            0               1              0                  0
# 343            1               1              0                  0
#
#      numeric_Adelie  numeric_Chinstrap  numeric_Gentoo
# 0                 1                  0               0
# 1                 1                  0               0
# 2                 1                  0               0
# 4                 1                  0               0
# 5                 1                  0               0
# ..              ...                ...             ...
# 338               0                  0               1
# 340               0                  0               1
# 341               0                  0               1
# 342               0                  0               1
# 343               0                  0               1
#
# [333 rows x 12 columns]

# %%
df_encoded.dtypes
# Out:
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# numeric_sex             int8
# numeric_Biscoe         int64
# numeric_Dream          int64
# numeric_Torgersen      int64
# numeric_Adelie         int64
# numeric_Chinstrap      int64
# numeric_Gentoo         int64
# dtype: object

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(
    data=df_encoded.corr(numeric_only=True),
    cmap=sns.diverging_palette(20,230,as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    cbar_kws={'shrink':0.5},
    annot=True
)
# Out:
# <Axes: >

# %% [markdown]
# # CLUSTERMAP

# %%
sns.clustermap(
    data=df_encoded.corr(numeric_only=True),
    cmap=sns.diverging_palette(20,230,as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    cbar_kws={'shrink':0.5},
    annot=True
)

# %% [markdown]
# # SUPONIENDO QUE LA VARIABLE DEPENDIENTE SEA EL SEXO, DETERMINAMOS LA VARIABLES CON MAYOR CORRELACIÓN PARA ESTE VARIABLE

# %%
corr_matrix = df_encoded.corr(numeric_only=True)
corr_age = corr_matrix[['numeric_sex']].sort_values(by='numeric_sex',ascending=False)
sns.heatmap(
    data=corr_age,
    cmap=sns.diverging_palette(20, 230, as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    cbar_kws={'shrink': 0.5},
    annot=True
)
# Out:
# <Axes: >
