# %% [markdown]
# # EXTENDIENDO LAS FUNCIONES DE PANDAS PARA ANALISIS DE DATOS NULOS

# %%
import pandas as pd

# %%
@pd.api.extensions.register_dataframe_accessor("missing")
class MissingMethods:

  def __init__(self,pandas_obj):
    self._df = pandas_obj

  def number_missing(self):
    return self._df.isnull().sum().sum()

# %%
df = pd.DataFrame.from_dict(
    data = {
        "a":list('asdfasdfas'),
        "b": range(0,10)
    }
)

df.iloc[2:5,0] = None
df.iloc[6:7,1] = None

df
# Out:
#       a    b
# 0     a  0.0
# 1     s  1.0
# 2  None  2.0
# 3  None  3.0
# 4  None  4.0
# 5     s  5.0
# 6     d  NaN
# 7     f  7.0
# 8     a  8.0
# 9     s  9.0

# %%
df_missing = MissingMethods(df)
total_missing = df_missing.number_missing()
total_missing
# Out:
# np.int64(4)

# %%
df.missing.number_missing()
# Out:
# np.int64(4)

# %% [markdown]
# # EJECUTAMOS EL NOTEBOOK PANDAS MISSING EXTENSION

# %%
# %run '/content/pandas_missing_extension.ipynb'

# %%
df = pd.DataFrame.from_dict(
    data = {
        "a": list('asdfasdfas'),
        "b": range(0,10)
    }
)
df.iloc[2:5,0] = None
df.iloc[6:7,1] = None
df
# Out:
#       a    b
# 0     a  0.0
# 1     s  1.0
# 2  None  2.0
# 3  None  3.0
# 4  None  4.0
# 5     s  5.0
# 6     d  NaN
# 7     f  7.0
# 8     a  8.0
# 9     s  9.0

# %%
print(f"total de valores: {df.size}")
print(f"total de valores missing: {df.missing.number_missing()}")
print(f"total de valores completos: {df.missing.number_complete()}")
# Out:
# total de valores: 20
# total de valores missing: 4
# total de valores completos: 16

# %%
df.missing.missing_variable_summary()
# Out:
#   variable  n_missing  n_cases  pct_missing
# 0        a          3       10         30.0
# 1        b          1       10         10.0

# %%
df.missing.missing_variable_plot()
